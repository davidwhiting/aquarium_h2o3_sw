# %% [markdown]
# # GLRM Showcase
#
# The following demo is taken from Anqi (the original GLRM author at H2O).
#
# I want to illustrate several things from this demo:
# - analyzing archetype (Y);
# - analyzing coefficients (X).
# - advantages of using GLRM to build your model.

# %%
library(h2o)
h2o.init(bind_to_localhost = FALSE, strict_version_check = FALSE)
# Out:
# ----------------------------------------------------------------------
#
# Your next step is to start H2O:
#     > h2o.init()
#
# For H2O package documentation, ask for help:
#     > ??h2o
#
# After starting H2O, you can use the Web UI at http://localhost:54321
# For more information visit http://docs.h2o.ai
#
# ----------------------------------------------------------------------
#
#
# Attaching package: 'h2o'
#
# The following objects are masked from 'package:stats':
#
#     cor, sd, var
#
# The following objects are masked from 'package:base':
#
#     %*%, %in%, &&, apply, as.factor, as.numeric, colnames, colnames<-,
#     ifelse, is.character, is.factor, is.numeric, log, log10, log1p,
#     log2, round, signif, trunc, ||
# H2O is not running yet, starting it now...
#
# Note:  In case of errors look at the following log files:
#     /tmp/Rtmp69Oa6U/h2o_UnknownUser_started_from_r.out
#     /tmp/Rtmp69Oa6U/h2o_UnknownUser_started_from_r.err
#
#
# Starting H2O JVM and connecting: . Connection successful!
#
# R is connected to the H2O cluster:
#     H2O cluster uptime:         1 seconds 413 milliseconds
#     H2O cluster timezone:       Etc/UTC
#     H2O data parsing timezone:  UTC
#     H2O cluster version:        3.24.0.5
#     H2O cluster version age:    1 month and 25 days
#     H2O cluster name:           H2O_started_from_R_h2o_nqc473
#     H2O cluster total nodes:    1
#     H2O cluster total memory:   13.98 GB
#     H2O cluster total cores:    16
#     H2O cluster allowed cores:  16
#     H2O cluster healthy:        TRUE
#     H2O Connection ip:          localhost
#     H2O Connection port:        54321
#     H2O Connection proxy:       NA
#     H2O Internal Security:      FALSE
#     H2O API Extensions:         Amazon S3, XGBoost, Algos, AutoML, Core V3, Core V4
#     R Version:                  R version 3.6.1 (2019-07-05)

# %% [markdown]
# ## Gait Data
#
# The following dataset contains information from various human subjects walking on a treadmill.  In particular, each subject is attached with sensors at the various joints.  Data from the sensors are collected.

# %%
#filename <- "http://s3.amazonaws.com/h2o-public-test-data/smalldata/glrm_test/subject01_walk1.csv"
filename <- "../../data/glrm/subject01_walk1.csv"
gait.hex <- h2o.importFile(path = filename, destination_frame = "gait.hex")
dim(gait.hex)
summary(gait.hex)
# Out:
#   |======================================================================| 100%
# [1] 151 124
# Warning message in summary.H2OFrame(gait.hex):
# "Approximated quantiles computed! If you are interested in exact quantiles, please pass the `exact_quantiles=TRUE` parameter."
#  Time             R.ASIS.X        R.ASIS.Y       R.ASIS.Z
#  Min.   :0.0000   Min.   :588.9   Min.   :1043   Min.   :107.8
#  1st Qu.:0.6238   1st Qu.:600.9   1st Qu.:1053   1st Qu.:123.3
#  Median :1.2500   Median :612.4   Median :1066   Median :148.3
#  Mean   :1.2500   Mean   :613.8   Mean   :1066   Mean   :147.3
#  3rd Qu.:1.8738   3rd Qu.:628.1   3rd Qu.:1079   3rd Qu.:172.4
#  Max.   :2.5000   Max.   :641.1   Max.   :1091   Max.   :180.1
#  L.ASIS.X        L.ASIS.Y       L.ASIS.Z          V.Sacral.X
#  Min.   :600.0   Min.   :1029   Min.   :-152.54   Min.   :399.4
#  1st Qu.:611.0   1st Qu.:1041   1st Qu.:-137.53   1st Qu.:408.0
#  Median :618.6   Median :1054   Median :-111.55   Median :418.6
#  Mean   :621.8   Mean   :1054   Mean   :-113.09   Mean   :419.6
#  3rd Qu.:625.9   3rd Qu.:1068   3rd Qu.: -88.24   3rd Qu.:430.0
#  Max.   :661.5   Max.   :1078   Max.   : -80.37   Max.   :451.6
#  V.Sacral.Y     V.Sacral.Z         R.Thigh.Upper.X R.Thigh.Upper.Y
#  Min.   :1035   Min.   :-21.4408   Min.   :481.8   Min.   :732.7
#  1st Qu.:1049   1st Qu.: -0.6251   1st Qu.:542.0   1st Qu.:740.6
#  Median :1059   Median : 22.9558   Median :631.7   Median :749.5
#  Mean   :1059   Mean   : 21.6235   Mean   :604.9   Mean   :752.1
#  3rd Qu.:1071   3rd Qu.: 45.4229   3rd Qu.:664.2   3rd Qu.:755.4
#  Max.   :1078   Max.   : 55.3699   Max.   :692.9   Max.   :788.1
#  R.Thigh.Upper.Z R.Thigh.Front.X R.Thigh.Front.Y R.Thigh.Front.Z
#  Min.   :169.7   Min.   :535.6   Min.   :657.2   Min.   : 74.21
#  1st Qu.:184.2   1st Qu.:602.0   1st Qu.:675.4   1st Qu.: 94.34
#  Median :202.1   Median :706.0   Median :699.5   Median :115.90
#  Mean   :198.4   Mean   :673.9   Mean   :697.9   Mean   :108.99
#  3rd Qu.:212.8   3rd Qu.:741.6   3rd Qu.:710.8   3rd Qu.:122.51
#  Max.   :217.1   Max.   :766.4   Max.   :750.7   Max.   :136.25
#  R.Thigh.Rear.X  R.Thigh.Rear.Y  R.Thigh.Rear.Z  L.Thigh.Upper.X
#  Min.   :443.0   Min.   :613.5   Min.   :168.2   Min.   :468.2
#  1st Qu.:518.7   1st Qu.:624.4   1st Qu.:180.7   1st Qu.:521.6
#  Median :644.4   Median :630.7   Median :196.2   Median :614.3
#  Mean   :611.8   Mean   :633.9   Mean   :191.2   Mean   :585.5
#  3rd Qu.:698.5   3rd Qu.:633.2   3rd Qu.:201.4   3rd Qu.:642.4
#  Max.   :728.7   Max.   :672.4   Max.   :209.9   Max.   :674.5
#  L.Thigh.Upper.Y L.Thigh.Upper.Z  L.Thigh.Front.X L.Thigh.Front.Y
#  Min.   :737.7   Min.   :-194.3   Min.   :550.7   Min.   :684.8
#  1st Qu.:747.4   1st Qu.:-179.8   1st Qu.:611.3   1st Qu.:707.0
#  Median :756.1   Median :-167.6   Median :710.1   Median :733.1
#  Mean   :757.0   Mean   :-165.3   Mean   :678.7   Mean   :728.7
#  3rd Qu.:764.0   3rd Qu.:-148.7   3rd Qu.:741.9   3rd Qu.:741.3
#  Max.   :783.7   Max.   :-138.1   Max.   :774.0   Max.   :780.8
#  L.Thigh.Front.Z   L.Thigh.Rear.X  L.Thigh.Rear.Y  L.Thigh.Rear.Z
#  Min.   :-133.59   Min.   :435.0   Min.   :627.5   Min.   :-170.9
#  1st Qu.:-122.69   1st Qu.:505.9   1st Qu.:643.5   1st Qu.:-160.5
#  Median :-111.59   Median :629.4   Median :650.6   Median :-154.8
#  Mean   :-105.36   Mean   :595.9   Mean   :651.8   Mean   :-150.8
#  3rd Qu.: -86.59   3rd Qu.:678.9   3rd Qu.:656.2   3rd Qu.:-138.2
#  Max.   : -66.30   Max.   :713.2   Max.   :681.4   Max.   :-123.2
#  R.Shank.Upper.X R.Shank.Upper.Y R.Shank.Upper.Z R.Shank.Front.X
#  Min.   :319.3   Min.   :444.4   Min.   :157.7   Min.   :376.4
#  1st Qu.:414.8   1st Qu.:456.7   1st Qu.:169.3   1st Qu.:472.7
#  Median :576.4   Median :465.6   Median :181.8   Median :629.0
#  Mean   :546.6   Mean   :475.6   Mean   :178.2   Mean   :612.1
#  3rd Qu.:674.9   3rd Qu.:488.3   3rd Qu.:185.5   3rd Qu.:758.9
#  Max.   :719.7   Max.   :531.1   Max.   :200.6   Max.   :799.5
#  R.Shank.Front.Y R.Shank.Front.Z R.Shank.Rear.X  R.Shank.Rear.Y
#  Min.   :403.3   Min.   :102.5   Min.   :293.9   Min.   :368.3
#  1st Qu.:414.6   1st Qu.:120.6   1st Qu.:393.7   1st Qu.:372.1
#  Median :421.2   Median :129.1   Median :557.2   Median :380.7
#  Mean   :427.5   Mean   :128.7   Mean   :542.3   Mean   :394.8
#  3rd Qu.:442.3   3rd Qu.:135.6   3rd Qu.:694.6   3rd Qu.:411.8
#  Max.   :457.6   Max.   :154.6   Max.   :751.9   Max.   :458.6
#  R.Shank.Rear.Z  L.Shank.Upper.X L.Shank.Upper.Y L.Shank.Upper.Z
#  Min.   :165.6   Min.   :341.2   Min.   :438.8   Min.   :-173.0
#  1st Qu.:176.4   1st Qu.:441.7   1st Qu.:441.1   1st Qu.:-159.3
#  Median :185.8   Median :608.6   Median :446.9   Median :-147.4
#  Mean   :183.8   Mean   :576.6   Mean   :453.6   Mean   :-145.6
#  3rd Qu.:189.6   3rd Qu.:709.7   3rd Qu.:457.6   3rd Qu.:-132.6
#  Max.   :202.6   Max.   :764.3   Max.   :494.4   Max.   :-116.5
#  L.Shank.Front.X L.Shank.Front.Y L.Shank.Front.Z   L.Shank.Rear.X
#  Min.   :365.7   Min.   :376.0   Min.   :-120.98   Min.   :304.5
#  1st Qu.:467.4   1st Qu.:387.4   1st Qu.:-107.24   1st Qu.:405.6
#  Median :631.1   Median :392.7   Median : -93.91   Median :576.3
#  Mean   :613.4   Mean   :399.5   Mean   : -93.86   Mean   :549.9
#  3rd Qu.:769.9   3rd Qu.:415.0   3rd Qu.: -82.74   3rd Qu.:696.5
#  Max.   :821.7   Max.   :425.6   Max.   : -63.52   Max.   :750.8
#  L.Shank.Rear.Y  L.Shank.Rear.Z   R.Heel.X        R.Heel.Y
#  Min.   :393.7   Min.   :-173.4   Min.   : 68.6   Min.   : 56.43
#  1st Qu.:396.9   1st Qu.:-163.7   1st Qu.:196.6   1st Qu.: 69.12
#  Median :406.2   Median :-152.3   Median :396.7   Median : 78.37
#  Mean   :418.0   Mean   :-150.9   Mean   :416.5   Mean   :129.32
#  3rd Qu.:432.1   3rd Qu.:-139.7   3rd Qu.:631.7   3rd Qu.:171.13
#  Max.   :473.0   Max.   :-124.5   Max.   :812.5   Max.   :320.70
#  R.Heel.Z         R.Midfoot.Sup.X R.Midfoot.Sup.Y  R.Midfoot.Sup.Z
#  Min.   : 59.95   Min.   :191.0   Min.   : 76.90   Min.   :57.87
#  1st Qu.: 89.70   1st Qu.:313.5   1st Qu.: 79.10   1st Qu.:61.65
#  Median : 92.49   Median :532.0   Median : 96.15   Median :69.47
#  Mean   : 90.86   Mean   :548.3   Mean   :111.61   Mean   :69.81
#  3rd Qu.: 95.94   3rd Qu.:777.4   3rd Qu.:131.54   3rd Qu.:75.32
#  Max.   :108.16   Max.   :935.6   Max.   :198.72   Max.   :86.31
#  R.Midfoot.Lat.X R.Midfoot.Lat.Y  R.Midfoot.Lat.Z R.Toe.Tip.X
#  Min.   :157.3   Min.   : 62.79   Min.   :160.0   Min.   : 242.9
#  1st Qu.:288.7   1st Qu.: 64.42   1st Qu.:168.2   1st Qu.: 419.5
#  Median :509.4   Median : 79.43   Median :175.3   Median : 664.2
#  Mean   :529.7   Mean   : 98.34   Mean   :174.2   Mean   : 666.9
#  3rd Qu.:757.3   3rd Qu.:110.86   3rd Qu.:178.4   3rd Qu.: 915.6
#  Max.   :934.4   Max.   :211.37   Max.   :188.7   Max.   :1073.9
#  R.Toe.Tip.Y      R.Toe.Tip.Z     L.Heel.X         L.Heel.Y
#  Min.   : 33.53   Min.   :102.1   Min.   : 76.38   Min.   : 58.75
#  1st Qu.: 45.12   1st Qu.:108.8   1st Qu.:216.88   1st Qu.: 74.53
#  Median : 50.58   Median :119.7   Median :418.51   Median : 81.90
#  Mean   : 65.95   Mean   :120.6   Mean   :434.37   Mean   :129.88
#  3rd Qu.: 68.14   3rd Qu.:129.6   3rd Qu.:657.78   3rd Qu.:168.57
#  Max.   :179.28   Max.   :153.6   Max.   :821.76   Max.   :321.80
#  L.Heel.Z         L.Midfoot.Sup.X L.Midfoot.Sup.Y  L.Midfoot.Sup.Z
#  Min.   :-74.04   Min.   :211.9   Min.   : 69.03   Min.   :-69.301
#  1st Qu.:-59.19   1st Qu.:352.0   1st Qu.: 76.33   1st Qu.:-36.942
#  Median :-48.89   Median :587.8   Median : 91.69   Median :-31.007
#  Mean   :-51.13   Mean   :586.8   Mean   :102.77   Mean   :-29.910
#  3rd Qu.:-43.78   3rd Qu.:825.1   3rd Qu.:127.22   3rd Qu.:-22.011
#  Max.   :-34.92   Max.   :971.3   Max.   :178.01   Max.   : -6.831
#  L.Midfoot.Lat.X L.Midfoot.Lat.Y  L.Midfoot.Lat.Z  L.Toe.Tip.X
#  Min.   :185.4   Min.   : 48.23   Min.   :-140.1   Min.   : 254.4
#  1st Qu.:332.9   1st Qu.: 68.10   1st Qu.:-129.8   1st Qu.: 437.0
#  Median :565.2   Median : 78.99   Median :-126.0   Median : 681.7
#  Mean   :567.2   Mean   : 96.34   Mean   :-123.8   Mean   : 681.1
#  3rd Qu.:804.7   3rd Qu.:117.66   3rd Qu.:-116.2   3rd Qu.: 937.2
#  Max.   :955.7   Max.   :184.36   Max.   :-104.4   Max.   :1082.5
#  L.Toe.Tip.Y      L.Toe.Tip.Z      Sternum.X       Sternum.Y
#  Min.   : 36.66   Min.   :-88.18   Min.   :627.4   Min.   :1343
#  1st Qu.: 46.36   1st Qu.:-66.38   1st Qu.:635.4   1st Qu.:1355
#  Median : 52.23   Median :-58.90   Median :641.9   Median :1369
#  Mean   : 67.46   Mean   :-57.79   Mean   :644.4   Mean   :1369
#  3rd Qu.: 70.12   3rd Qu.:-45.66   3rd Qu.:650.2   3rd Qu.:1383
#  Max.   :168.65   Max.   :-32.92   Max.   :673.9   Max.   :1394
#  Sternum.Z         R.Acromium.X    R.Acromium.Y   R.Acromium.Z
#  Min.   :-35.208   Min.   :511.8   Min.   :1427   Min.   :164.5
#  1st Qu.:-18.982   1st Qu.:535.6   1st Qu.:1447   1st Qu.:182.8
#  Median : 10.747   Median :540.9   Median :1460   Median :216.4
#  Mean   :  7.558   Mean   :541.7   Mean   :1459   Mean   :215.4
#  3rd Qu.: 35.303   3rd Qu.:551.1   3rd Qu.:1472   3rd Qu.:249.3
#  Max.   : 43.752   Max.   :573.7   Max.   :1486   Max.   :262.1
#  L.Acromium.X    L.Acromium.Y   L.Acromium.Z     R.Bicep.X       R.Bicep.Y
#  Min.   :551.7   Min.   :1454   Min.   :-249.9   Min.   :485.9   Min.   :1228
#  1st Qu.:563.7   1st Qu.:1466   1st Qu.:-232.1   1st Qu.:515.8   1st Qu.:1248
#  Median :579.6   Median :1480   Median :-198.7   Median :556.4   Median :1260
#  Mean   :579.5   Mean   :1481   Mean   :-200.6   Mean   :547.0   Mean   :1259
#  3rd Qu.:591.1   3rd Qu.:1493   3rd Qu.:-167.7   3rd Qu.:575.4   3rd Qu.:1271
#  Max.   :609.4   Max.   :1508   Max.   :-155.9   Max.   :593.6   Max.   :1289
#  R.Bicep.Z       L.Bicep.X       L.Bicep.Y      L.Bicep.Z
#  Min.   :216.1   Min.   :531.1   Min.   :1218   Min.   :-266.6
#  1st Qu.:235.1   1st Qu.:557.3   1st Qu.:1231   1st Qu.:-251.3
#  Median :263.2   Median :609.9   Median :1244   Median :-228.9
#  Mean   :262.8   Mean   :596.1   Mean   :1244   Mean   :-229.9
#  3rd Qu.:291.7   3rd Qu.:626.3   3rd Qu.:1256   3rd Qu.:-206.0
#  Max.   :305.9   Max.   :643.9   Max.   :1272   Max.   :-196.6
#  R.Elbow.X       R.Elbow.Y      R.Elbow.Z       L.Elbow.X       L.Elbow.Y
#  Min.   :424.3   Min.   :1129   Min.   :242.3   Min.   :460.0   Min.   :1124
#  1st Qu.:458.9   1st Qu.:1143   1st Qu.:262.7   1st Qu.:496.1   1st Qu.:1133
#  Median :514.2   Median :1156   Median :291.5   Median :563.4   Median :1146
#  Mean   :504.2   Mean   :1158   Mean   :292.1   Mean   :548.3   Mean   :1149
#  3rd Qu.:549.2   3rd Qu.:1171   3rd Qu.:322.6   3rd Qu.:596.6   3rd Qu.:1160
#  Max.   :567.0   Max.   :1193   Max.   :339.8   Max.   :608.9   Max.   :1186
#  L.Elbow.Z        R.Wrist.Med.X   R.Wrist.Med.Y    R.Wrist.Med.Z
#  Min.   :-304.8   Min.   :535.9   Min.   : 889.8   Min.   :262.1
#  1st Qu.:-289.5   1st Qu.:583.5   1st Qu.: 921.9   1st Qu.:270.2
#  Median :-269.2   Median :660.2   Median : 943.7   Median :280.3
#  Mean   :-267.9   Mean   :659.5   Mean   : 943.8   Mean   :282.8
#  3rd Qu.:-243.7   3rd Qu.:739.9   3rd Qu.: 964.3   3rd Qu.:292.9
#  Max.   :-230.9   Max.   :772.6   Max.   :1003.1   Max.   :313.0
#  R.Wrist.Lat.X   R.Wrist.Lat.Y   R.Wrist.Lat.Z   L.Wrist.Med.X
#  Min.   :487.0   Min.   :876.5   Min.   :304.7   Min.   :554.4
#  1st Qu.:536.0   1st Qu.:907.5   1st Qu.:319.6   1st Qu.:595.1
#  Median :616.7   Median :930.0   Median :330.9   Median :661.2
#  Mean   :620.9   Mean   :926.0   Mean   :331.3   Mean   :672.9
#  3rd Qu.:711.9   3rd Qu.:941.7   3rd Qu.:341.3   3rd Qu.:752.9
#  Max.   :751.6   Max.   :969.9   Max.   :362.0   Max.   :793.9
#  L.Wrist.Med.Y   L.Wrist.Med.Z    L.Wrist.Lat.X   L.Wrist.Lat.Y
#  Min.   :895.9   Min.   :-240.6   Min.   :502.8   Min.   :886.6
#  1st Qu.:916.1   1st Qu.:-224.2   1st Qu.:547.0   1st Qu.:906.1
#  Median :935.9   Median :-214.1   Median :617.8   Median :923.6
#  Mean   :938.1   Mean   :-214.6   Mean   :631.5   Mean   :922.0
#  3rd Qu.:951.5   3rd Qu.:-206.5   3rd Qu.:716.9   3rd Qu.:937.5
#  Max.   :998.8   Max.   :-188.3   Max.   :768.9   Max.   :958.3
#  L.Wrist.Lat.Z    R.Toe.Lat.X      R.Toe.Lat.Y      R.Toe.Lat.Z
#  Min.   :-300.9   Min.   : 179.8   Min.   : 33.33   Min.   :181.2
#  1st Qu.:-283.3   1st Qu.: 352.4   1st Qu.: 38.09   1st Qu.:186.6
#  Median :-274.6   Median : 595.3   Median : 43.17   Median :195.0
#  Mean   :-274.0   Mean   : 601.5   Mean   : 61.90   Mean   :194.7
#  3rd Qu.:-263.9   3rd Qu.: 842.0   3rd Qu.: 82.21   3rd Qu.:198.7
#  Max.   :-249.4   Max.   :1026.0   Max.   :136.90   Max.   :218.5
#  R.Toe.Med.X      R.Toe.Med.Y      R.Toe.Med.Z      L.Toe.Lat.X
#  Min.   : 218.0   Min.   : 36.96   Min.   : 71.79   Min.   : 199.8
#  1st Qu.: 374.7   1st Qu.: 45.05   1st Qu.: 79.29   1st Qu.: 370.8
#  Median : 608.5   Median : 51.16   Median : 85.96   Median : 617.7
#  Mean   : 619.8   Mean   : 68.49   Mean   : 86.62   Mean   : 618.3
#  3rd Qu.: 864.2   3rd Qu.: 88.82   3rd Qu.: 92.71   3rd Qu.: 867.9
#  Max.   :1029.9   Max.   :153.35   Max.   :113.46   Max.   :1024.1
#  L.Toe.Lat.Y      L.Toe.Lat.Z      L.Toe.Med.X      L.Toe.Med.Y
#  Min.   : 36.03   Min.   :-153.1   Min.   : 228.0   Min.   : 42.97
#  1st Qu.: 41.13   1st Qu.:-140.9   1st Qu.: 392.8   1st Qu.: 49.18
#  Median : 50.04   Median :-134.2   Median : 635.3   Median : 57.26
#  Mean   : 65.93   Mean   :-132.6   Mean   : 638.6   Mean   : 72.32
#  3rd Qu.: 89.70   3rd Qu.:-123.5   3rd Qu.: 887.7   3rd Qu.: 93.08
#  Max.   :133.35   Max.   :-111.9   Max.   :1039.4   Max.   :146.50
#  L.Toe.Med.Z       R.Temple.X      R.Temple.Y     R.Temple.Z
#  Min.   :-54.889   Min.   :676.0   Min.   :1562   Min.   : 44.15
#  1st Qu.:-40.096   1st Qu.:687.7   1st Qu.:1583   1st Qu.: 62.92
#  Median :-33.211   Median :706.4   Median :1598   Median : 94.98
#  Mean   :-31.813   Mean   :705.7   Mean   :1598   Mean   : 94.05
#  3rd Qu.:-22.781   3rd Qu.:720.2   3rd Qu.:1611   3rd Qu.:126.14
#  Max.   : -9.442   Max.   :740.6   Max.   :1640   Max.   :139.16
#  L.Temple.X      L.Temple.Y     L.Temple.Z        Top.Head.X
#  Min.   :683.5   Min.   :1567   Min.   :-94.075   Min.   :614.1
#  1st Qu.:702.1   1st Qu.:1586   1st Qu.:-74.900   1st Qu.:653.3
#  Median :718.5   Median :1604   Median :-43.196   Median :717.0
#  Mean   :718.7   Mean   :1603   Mean   :-44.319   Mean   :698.9
#  3rd Qu.:734.3   3rd Qu.:1615   3rd Qu.:-12.678   3rd Qu.:733.4
#  Max.   :754.6   Max.   :1648   Max.   :  0.849   Max.   :752.9
#  Top.Head.Y     Top.Head.Z
#  Min.   :1740   Min.   :-19.4884
#  1st Qu.:1759   1st Qu.:  0.1594
#  Median :1775   Median : 33.9535
#  Mean   :1773   Mean   : 33.5554
#  3rd Qu.:1784   3rd Qu.: 67.1712
#  Max.   :1809   Max.   : 85.2995

# %% [markdown]
# We will build a GLRM model using quadratic loss and no regularization since the dataset contains only numeric features.  Skip the first column (time) and set k=10.

# %%
gait.glrm <- h2o.glrm(training_frame = gait.hex, cols = 2:ncol(gait.hex), k = 10, loss = "Quadratic", 
                      regularization_x = "None", regularization_y = "None", max_iterations = 1000)
# Out:
#   |======================================================================| 100%

# %% [markdown]
# The dataset basically contains the spatial information of a user's head, temple, toes, wrists, elbows, biceps, sternum, acromium (shoulder above arm joint), midfoots, heels, rear/upper shank, thigh, ....  What do you think the archetypes will look like?

# %%
gait.y <- gait.glrm@model$archetypes
gait.y.mat <- as.matrix(gait.y)
x_coords <- seq(1, ncol(gait.y), by = 3)
y_coords <- seq(2, ncol(gait.y), by = 3)
feat_nams <- sapply(colnames(gait.y), function(nam) { substr(nam, 1, nchar(nam)-1) })
feat_nams <- as.character(feat_nams[x_coords])
for(k in 1:10) {
    plot(gait.y.mat[k,x_coords], gait.y.mat[k,y_coords], xlab = "X-Coordinate Weight", ylab = "Y-Coordinate Weight", main = paste("Feature Weights of Archetype", k), col = "blue", pch = 19, lty = "solid")
    text(gait.y.mat[k,x_coords], gait.y.mat[k,y_coords], labels = feat_nams, cex = 0.7, pos = 3)

}
# Out:
# Plot with title "Feature Weights of Archetype 1"
# Plot with title "Feature Weights of Archetype 2"
# Plot with title "Feature Weights of Archetype 3"
# Plot with title "Feature Weights of Archetype 4"
# Plot with title "Feature Weights of Archetype 5"
# Plot with title "Feature Weights of Archetype 6"
# Plot with title "Feature Weights of Archetype 7"
# Plot with title "Feature Weights of Archetype 8"
# Plot with title "Feature Weights of Archetype 9"
# Plot with title "Feature Weights of Archetype 10"

# %% [markdown]
# Next, we want to understand if we break our data into A=XY, for a given set of Y, what can we use X for?  What can X show us?

# %% [markdown]
# ## ACS Data
#
# In this example, we want to predict whether a firm will repeat an offense or not after a compliance action has been carried out on a firm.  The dataset collected here includes information on each investigation, including zip code (ZCTA) where the firm is located, number of violations found, civil penalities assessed.  The zipcode data by itself is not meaningful.  In fact, it is a categorical data with high cardinality (42000).  If we use one hot encoding to expand the zip code column into 42000 columns, our model will run slowly and probably overfit.
#
# Instead, we choose to user the American Community Survey (ACS) 5-year estimates of household characteristics dataset to expand our zip code column.  Each row of ACS contains information for a unique zip code, other information like household size, income, education level, number of children, etc.

# %%
#filename <- "http://s3.amazonaws.com/h2o-public-test-data/bigdata/laptop/census/ACS_13_5YR_DP02_cleaned.zip"
filename <- "../../data/glrm//ACS_13_5YR_DP02_cleaned.zip"
acs_orig <- h2o.importFile(path = filename, col.types = c("enum", rep("numeric", 149)))
# Out:
#   |======================================================================| 100%

# %%
dim(acs_orig)
summary(acs_orig)
# Out:
# [1] 32989   150
# Warning message in summary.H2OFrame(acs_orig):
# "Approximated quantiles computed! If you are interested in exact quantiles, please pass the `exact_quantiles=TRUE` parameter."
#  ZCTA5    total_households  family_households families_w_children_under_18
#  01001:1  Min.   :    0.0   Min.   :    0.0   Min.   :    0.00
#  01002:1  1st Qu.:  260.5   1st Qu.:  171.9   1st Qu.:   61.22
#  01003:1  Median : 1042.1   Median :  716.2   Median :  275.51
#  01005:1  Mean   : 3504.5   Mean   : 2326.3   Mean   : 1035.66
#  01007:1  3rd Qu.: 4776.4   3rd Qu.: 3208.8   3rd Qu.: 1331.62
#  01008:1  Max.   :43421.0   Max.   :28649.0   Max.   :15305.00
#
#  married_families  married_w_children_under_18 male_no_wife
#  Min.   :    0.0   Min.   :    0.00            Min.   :   0.000
#  1st Qu.:  138.6   1st Qu.:   34.06            1st Qu.:   8.168
#  Median :  554.5   Median :  192.98            Median :  44.924
#  Mean   : 1706.8   Mean   :  699.79            Mean   : 164.754
#  3rd Qu.: 2336.8   3rd Qu.:  874.10            3rd Qu.: 196.032
#  Max.   :19802.0   Max.   :11351.00            Max.   :4083.000
#
#  male_no_wife_w_children_under_18 female_no_husband
#  Min.   :   0.00                  Min.   :    0.00
#  1st Qu.:   0.00                  1st Qu.:   12.90
#  Median :  19.42                  Median :   90.29
#  Mean   :  79.55                  Mean   :  454.80
#  3rd Qu.:  94.95                  3rd Qu.:  515.96
#  Max.   :2157.00                  Max.   :12898.00
#
#  female_no_husband_w_children_under_18 nonfamily_households living_alone
#  Min.   :   0.000                      Min.   :    0.00     Min.   :    0.00
#  1st Qu.:   7.367                      1st Qu.:   53.14     1st Qu.:   58.78
#  Median :  51.569                      Median :  292.27     Median :  254.72
#  Mean   : 256.322                      Mean   : 1178.13     Mean   :  963.30
#  3rd Qu.: 279.946                      3rd Qu.: 1434.78     3rd Qu.: 1214.83
#  Max.   :7366.000                      Max.   :26569.00     Max.   :19593.00
#
#  living_alone_65_and_over households_w_people_under_18
#  Min.   :   0.00          Min.   :    0.00
#  1st Qu.:  23.43          1st Qu.:   68.96
#  Median : 101.54          Median :  310.34
#  Mean   : 342.41          Mean   : 1154.31
#  3rd Qu.: 445.23          3rd Qu.: 1499.97
#  Max.   :7810.00          Max.   :17240.00
#
#  households_w_people_over_65 average_household_size average_family_size
#  Min.   :    0.00            Min.   : 0.000         Min.   : 0.000
#  1st Qu.:   65.39            1st Qu.: 2.281         1st Qu.: 2.819
#  Median :  283.33            Median : 2.514         Median : 3.037
#  Mean   :  892.33            Mean   : 2.510         Mean   : 3.013
#  3rd Qu.: 1220.52            3rd Qu.: 2.746         3rd Qu.: 3.255
#  Max.   :21794.00            Max.   :14.530         Max.   :14.530
#
#  pop_in_households  pop_householder   pop_spouse        pop_child
#  Min.   :     0.0   Min.   :    0.0   Min.   :    0.0   Min.   :    0.0
#  1st Qu.:   571.8   1st Qu.:  260.5   1st Qu.:  138.5   1st Qu.:  137.1
#  Median :  2630.1   Median : 1042.1   Median :  554.0   Median :  731.4
#  Mean   :  9200.2   Mean   : 3504.5   Mean   : 1705.8   Mean   : 2811.0
#  3rd Qu.: 12350.2   3rd Qu.: 4776.4   3rd Qu.: 2334.5   3rd Qu.: 3565.7
#  Max.   :114353.0   Max.   :43421.0   Max.   :19783.0   Max.   :45713.0
#
#  pop_other_relatives pop_nonrelatives   pop_unmarried_partner males_15_and_over
#  Min.   :    0.00    Min.   :    0.00   Min.   :   0.00       Min.   :    0.0
#  1st Qu.:   21.87    1st Qu.:   15.96   1st Qu.:   8.25       1st Qu.:  277.5
#  Median :  131.20    Median :   95.77   Median :  53.62       Median : 1110.1
#  Mean   :  650.39    Mean   :  528.51   Mean   : 206.78       Mean   : 3698.0
#  3rd Qu.:  656.01    3rd Qu.:  542.71   3rd Qu.: 247.50       3rd Qu.: 5041.9
#  Max.   :21866.00    Max.   :15961.00   Max.   :4124.00       Max.   :46255.0
#
#  males_15_and_over_unmarried males_15_and_over_married
#  Min.   :    0.00            Min.   :    0.0
#  1st Qu.:   70.36            1st Qu.:  154.3
#  Median :  304.90            Median :  595.1
#  Mean   : 1310.73            Mean   : 1872.2
#  3rd Qu.: 1594.87            3rd Qu.: 2534.5
#  Max.   :23453.00            Max.   :22038.0
#
#  males_15_and_over_separated males_15_and_over_widowed
#  Min.   :   0.00             Min.   :   0.00
#  1st Qu.:   0.00             1st Qu.:   5.50
#  Median :  13.70             Median :  30.25
#  Mean   :  68.03             Mean   :  94.19
#  3rd Qu.:  75.33             3rd Qu.: 127.88
#  Max.   :1711.00             Max.   :1374.00
#
#  males_15_and_over_divorced females_15_and_over females_15_and_over_unmarried
#  Min.   :   0.00            Min.   :    0.0     Min.   :    0.0
#  1st Qu.:  26.52            1st Qu.:  285.3     1st Qu.:   46.6
#  Median : 114.92            Median : 1093.5     Median :  233.0
#  Mean   : 352.85            Mean   : 3892.1     Mean   : 1133.3
#  3rd Qu.: 481.78            3rd Qu.: 5277.3     3rd Qu.: 1304.7
#  Max.   :4419.00            Max.   :47542.0     Max.   :23297.0
#
#  females_15_and_over_married females_15_and_over_separated
#  Min.   :    0.0             Min.   :   0.00
#  1st Qu.:  151.5             1st Qu.:   0.00
#  Median :  584.4             Median :  16.52
#  Mean   : 1830.8             Mean   :  97.91
#  3rd Qu.: 2489.2             3rd Qu.: 105.73
#  Max.   :21644.0             Max.   :3303.00
#
#  females_15_and_over_widowed females_15_and_over_divorced women_birth_past_year
#  Min.   :   0.00             Min.   :   0.00              Min.   :   0.000
#  1st Qu.:  21.98             1st Qu.:  25.34              1st Qu.:   3.678
#  Median : 109.88             Median : 120.38              Median :  25.746
#  Mean   : 359.88             Mean   : 470.14              Mean   : 123.410
#  3rd Qu.: 488.97             3rd Qu.: 614.59              3rd Qu.: 143.442
#  Max.   :5493.00             Max.   :6335.00              Max.   :3677.000
#                                                           NA's   :441
#  unmarried_women_birth_past_year unmarried_women_birth_past_year_per_1000
#  Min.   :   0.000                Min.   :   0.00
#  1st Qu.:   0.000                1st Qu.:   0.00
#  Median :   5.056                Median :  14.01
#  Mean   :  43.868                Mean   :  35.03
#  3rd Qu.:  40.448                3rd Qu.:  46.05
#  Max.   :2527.000                Max.   :1000.00
#  NA's   :441                     NA's   :441
#  women_birth_past_year_per_1000 women_15_to_19_birth_past_year_per_1000
#  Min.   :   0.00                Min.   :   0.000
#  1st Qu.:  15.02                1st Qu.:   0.000
#  Median :  44.04                Median :   0.000
#  Mean   :  52.78                Mean   :  21.418
#  3rd Qu.:  68.07                3rd Qu.:   7.007
#  Max.   :1000.00                Max.   :1000.000
#  NA's   :441                    NA's   :441
#  women_20_to_34_birth_past_year_per_1000
#  Min.   :   0.00
#  1st Qu.:  11.01
#  Median :  83.08
#  Mean   : 104.20
#  3rd Qu.: 137.14
#  Max.   :1000.00
#  NA's   :441
#  women_35_to_50_birth_past_year_per_1000 grdparents_live_w_grdchildren
#  Min.   :   0.000                        Min.   :   0.00
#  1st Qu.:   0.000                        1st Qu.:   0.00
#  Median :   1.001                        Median :  49.01
#  Mean   :  18.659                        Mean   : 212.91
#  3rd Qu.:  25.025                        3rd Qu.: 224.06
#  Max.   :1000.000                        Max.   :7001.00
#  NA's   :441
#  grdparents_live_w_resp_grdchildren resp_grdchildren_less_1yr
#  Min.   :   0.00                    Min.   :  0.00
#  1st Qu.:   0.00                    1st Qu.:  0.00
#  Median :  19.69                    Median :  0.00
#  Mean   :  82.87                    Mean   : 17.78
#  3rd Qu.:  94.08                    3rd Qu.: 18.00
#  Max.   :2187.00                    Max.   :604.00
#
#  resp_grdchildren_1_or_2yrs resp_grdchildren_3_or_4yrs
#  Min.   :  0.00             Min.   :  0.0
#  1st Qu.:  0.00             1st Qu.:  0.0
#  Median :  0.00             Median :  0.0
#  Mean   : 19.72             Mean   : 13.8
#  3rd Qu.: 20.00             3rd Qu.: 13.0
#  Max.   :510.00             Max.   :556.0
#
#  resp_grdchildren_5yrs_or_more grdparents_resp_grdchildren
#  Min.   :  0.00                Min.   :   0.00
#  1st Qu.:  0.00                1st Qu.:   0.00
#  Median :  4.00                Median :  19.69
#  Mean   : 31.58                Mean   :  82.87
#  3rd Qu.: 35.00                3rd Qu.:  94.08
#  Max.   :796.00                Max.   :2187.00
#
#  female_grdparents_resp_grdchildren married_grdparents_resp_grdchildren
#  Min.   :   0.00                    Min.   :   0.00
#  1st Qu.:   0.00                    1st Qu.:   0.00
#  Median :  10.95                    Median :  12.39
#  Mean   :  51.93                    Mean   :  58.41
#  3rd Qu.:  57.50                    3rd Qu.:  66.61
#  Max.   :1368.00                    Max.   :1548.00
#
#  pop_3_and_over_in_school nursery_and_preschool kindergarten
#  Min.   :    0.0          Min.   :   0.000      Min.   :   0.000
#  1st Qu.:  119.9          1st Qu.:   3.237      1st Qu.:   3.222
#  Median :  639.6          Median :  35.607      Median :  32.220
#  Mean   : 2504.5          Mean   : 151.904      Mean   : 127.568
#  3rd Qu.: 3198.2          3rd Qu.: 190.983      3rd Qu.: 157.878
#  Max.   :39977.0          Max.   :3236.000      Max.   :3221.000
#
#  elementary_school  high_school       college_or_graduate_school
#  Min.   :    0.00   Min.   :   0.00   Min.   :    0.0
#  1st Qu.:   50.55   1st Qu.:  27.77   1st Qu.:    0.0
#  Median :  269.58   Median : 138.82   Median :  109.6
#  Mean   :  994.16   Mean   : 519.95   Mean   :  711.0
#  3rd Qu.: 1263.67   3rd Qu.: 657.11   3rd Qu.:  731.0
#  Max.   :16848.00   Max.   :9254.00   Max.   :36548.0
#
#  pop_25_years_and_over less_than_9th_grade high_school_no_diploma
#  Min.   :    0         Min.   :    0.00    Min.   :    0.00
#  1st Qu.:  439         1st Qu.:    0.00    1st Qu.:   26.46
#  Median : 1829         Median :   72.02    Median :  145.52
#  Mean   : 6262         Mean   :  372.01    Mean   :  503.60
#  3rd Qu.: 8634         3rd Qu.:  312.09    3rd Qu.:  582.08
#  Max.   :73169         Max.   :24006.00    Max.   :13228.00
#
#  high_school_graduate college_no_degree  associate_degree  bachelors_degree
#  Min.   :    0.0      Min.   :    0.00   Min.   :   0.00   Min.   :    0.00
#  1st Qu.:  171.6      1st Qu.:   84.98   1st Qu.:  31.62   1st Qu.:   24.26
#  Median :  661.8      Median :  390.93   Median : 145.45   Median :  194.06
#  Mean   : 1760.6      Mean   : 1330.58   Mean   : 489.11   Mean   : 1130.24
#  3rd Qu.: 2377.5      3rd Qu.: 1750.69   3rd Qu.: 638.72   3rd Qu.: 1237.11
#  Max.   :24509.0      Max.   :16996.00   Max.   :6323.00   Max.   :24256.00
#
#  graduate_or_prof_degree pct_high_school_grad_or_higher
#  Min.   :    0.00        Min.   :  0.00
#  1st Qu.:    0.00        1st Qu.: 80.50
#  Median :   84.96        Median : 88.00
#  Mean   :  675.88        Mean   : 84.72
#  3rd Qu.:  651.34        3rd Qu.: 93.00
#  Max.   :28318.00        Max.   :100.00
#
#  pct_bachelors_degree_or_higher civilian_18_and_over civilian_veterans
#  Min.   :  0.00                 Min.   :    0.0      Min.   :    0.0
#  1st Qu.: 11.10                 1st Qu.:  502.9      1st Qu.:   51.4
#  Median : 17.50                 Median : 2095.4      Median :  218.5
#  Mean   : 21.86                 Mean   : 7171.1      Mean   :  644.5
#  3rd Qu.: 28.30                 3rd Qu.: 9806.7      3rd Qu.:  873.9
#  Max.   :100.00                 Max.   :83817.0      Max.   :12850.0
#
#  pop_civilian_noninst pop_civilian_w_disability age_under_18
#  Min.   :     0.0     Min.   :    0.00          Min.   :    0.0
#  1st Qu.:   682.9     1st Qu.:   88.04          1st Qu.:  122.1
#  Median :  2617.9     Median :  381.52          Median :  610.4
#  Mean   :  9289.3     Mean   : 1126.69          Mean   : 2235.1
#  3rd Qu.: 12520.4     3rd Qu.: 1540.77          3rd Qu.: 2848.4
#  Max.   :113821.0     Max.   :14673.00          Max.   :40691.0
#
#  age_under_18_w_disability age_18_to_64      age_18_to_64_w_disability
#  Min.   :   0.00           Min.   :    0.0   Min.   :    0.00
#  1st Qu.:   0.00           1st Qu.:  363.7   1st Qu.:   41.22
#  Median :  24.23           Median : 1600.3   Median :  195.79
#  Mean   :  90.11           Mean   : 5825.1   Mean   :  588.18
#  3rd Qu.: 109.03           3rd Qu.: 7710.3   3rd Qu.:  772.88
#  Max.   :2422.00           Max.   :72738.0   Max.   :10304.00
#
#  age_65_and_over   age_65_and_over_w_disability pop_1_and_over
#  Min.   :    0.0   Min.   :   0.00              Min.   :     0.0
#  1st Qu.:  103.7   1st Qu.:  38.42              1st Qu.:   681.3
#  Median :  415.0   Median : 153.70              Median :  2725.3
#  Mean   : 1229.0   Mean   : 448.39              Mean   :  9329.8
#  3rd Qu.: 1659.9   3rd Qu.: 614.78              3rd Qu.: 12604.7
#  Max.   :34581.0   Max.   :9605.00              Max.   :113555.0
#
#  res_same_house     res_diff_house_in_us res_same_county    res_diff_county
#  Min.   :     0.0   Min.   :    0.00     Min.   :    0.00   Min.   :    0.00
#  1st Qu.:   601.3   1st Qu.:   54.65     1st Qu.:   16.63   1st Qu.:   13.29
#  Median :  2405.1   Median :  273.27     Median :  133.06   Median :  119.59
#  Mean   :  7920.2   Mean   : 1354.58     Mean   :  848.79   Mean   :  505.79
#  3rd Qu.: 10822.9   3rd Qu.: 1584.97     3rd Qu.:  898.18   3rd Qu.:  597.96
#  Max.   :100211.0   Max.   :27326.00     Max.   :16632.00   Max.   :13287.00
#
#  res_diff_county_same_state res_diff_county_and_state res_abroad
#  Min.   :    0.00           Min.   :    0.00          Min.   :   0.00
#  1st Qu.:    0.00           1st Qu.:    0.00          1st Qu.:   0.00
#  Median :   59.25           Median :   30.68          Median :   0.00
#  Mean   :  294.71           Mean   :  211.07          Mean   :  55.00
#  3rd Qu.:  319.95           3rd Qu.:  214.79          3rd Qu.:  31.43
#  Max.   :11849.00           Max.   :10227.00          Max.   :3928.00
#
#  total_pop_place_of_birth pop_native        native_born_in_us
#  Min.   :     0.0         Min.   :    0.0   Min.   :    0.0
#  1st Qu.:   688.4         1st Qu.:  617.6   1st Qu.:  689.7
#  Median :  2753.6         Median : 2646.9   Median : 2586.4
#  Mean   :  9443.2         Mean   : 8220.3   Mean   : 8088.3
#  3rd Qu.: 12735.6         3rd Qu.:11646.2   3rd Qu.:11466.6
#  Max.   :114734.0         Max.   :88228.0   Max.   :86214.0
#
#  born_state_of_residence born_different_state born_islands_american_abroad
#  Min.   :    0.0         Min.   :    0.0      Min.   :    0.0
#  1st Qu.:  422.3         1st Qu.:  137.0      1st Qu.:    0.0
#  Median : 1829.8         Median :  593.8      Median :    0.0
#  Mean   : 5547.3         Mean   : 2541.0      Mean   :  132.1
#  3rd Qu.: 7460.0         3rd Qu.: 2969.1      3rd Qu.:  100.1
#  Max.   :70376.0         Max.   :45677.0      Max.   :12507.0
#
#  total_pop_foreign_born pop_foreign_born  foreign_born_naturalized_us_citizen
#  Min.   :    0.0        Min.   :    0.0   Min.   :    0.0
#  1st Qu.:    0.0        1st Qu.:    0.0   1st Qu.:    0.0
#  Median :    0.0        Median :    0.0   Median :    0.0
#  Mean   : 1222.8        Mean   : 1222.8   Mean   :  551.9
#  3rd Qu.:  624.8        3rd Qu.:  624.8   3rd Qu.:  260.3
#  Max.   :69424.0        Max.   :69424.0   Max.   :32541.0
#
#  foreign_born_not_us_citizen pop_born_outside_us native
#  Min.   :    0.0             Min.   :    0.00    Min.   :    0.0
#  1st Qu.:    0.0             1st Qu.:    0.00    1st Qu.:    0.0
#  Median :    0.0             Median :   70.78    Median :    0.0
#  Mean   :  670.9             Mean   : 1354.92    Mean   :  132.1
#  3rd Qu.:  285.2             3rd Qu.:  707.76    3rd Qu.:  100.1
#  Max.   :47531.0             Max.   :70775.00    Max.   :12507.0
#
#  native_entered_2010_or_later native_entered_before_2010 foreign_born
#  Min.   :   0.000             Min.   :    0.00           Min.   :    0.0
#  1st Qu.:   0.000             1st Qu.:    0.00           1st Qu.:    0.0
#  Median :   0.000             Median :   11.33           Median :    0.0
#  Mean   :   5.674             Mean   :  126.41           Mean   : 1222.8
#  3rd Qu.:   0.000             3rd Qu.:   90.67           3rd Qu.:  624.8
#  Max.   :1174.000             Max.   :11333.00           Max.   :69424.0
#
#  foreign_born_entered_2010_or_later foreign_born_entered_before_2010
#  Min.   :   0.00                    Min.   :    0.0
#  1st Qu.:   0.00                    1st Qu.:    0.0
#  Median :   0.00                    Median :    0.0
#  Mean   :  56.98                    Mean   : 1165.9
#  3rd Qu.:  18.69                    3rd Qu.:  534.3
#  Max.   :3737.00                    Max.   :66787.0
#
#  foreign_born_excl_born_at_sea foreign_born_europe foreign_born_asia
#  Min.   :    0.0               Min.   :    0.00    Min.   :    0.00
#  1st Qu.:    0.0               1st Qu.:    0.00    1st Qu.:    0.00
#  Median :    0.0               Median :    0.00    Median :    0.00
#  Mean   : 1222.8               Mean   :  146.12    Mean   :  352.38
#  3rd Qu.:  624.8               3rd Qu.:   86.47    3rd Qu.:   97.62
#  Max.   :69424.0               Max.   :28823.00    Max.   :48809.00
#
#  foreign_born_africa foreign_born_oceania foreign_born_latin_america
#  Min.   :   0.000    Min.   :   0.000     Min.   :    0.0
#  1st Qu.:   0.000    1st Qu.:   0.000     1st Qu.:    0.0
#  Median :   0.000    Median :   0.000     Median :    0.0
#  Mean   :  50.435    Mean   :   6.834     Mean   :  642.2
#  3rd Qu.:   7.627    3rd Qu.:   0.000     3rd Qu.:  165.1
#  Max.   :7626.000    Max.   :2614.000     Max.   :55018.0
#
#  foreign_born_northern_america pop_5_and_over     english_language_only
#  Min.   :   0.00               Min.   :     0.0   Min.   :    0.0
#  1st Qu.:   0.00               1st Qu.:   634.2   1st Qu.:  602.1
#  Median :   0.00               Median :  2536.7   Median : 2341.4
#  Mean   :  24.83               Mean   :  8835.3   Mean   : 7005.7
#  3rd Qu.:  15.18               3rd Qu.: 11943.8   3rd Qu.: 9967.8
#  Max.   :2168.00               Max.   :105696.0   Max.   :66897.0
#
#  non_english_language non_english_poor_english spanish_language
#  Min.   :    0.00     Min.   :    0.0          Min.   :    0.0
#  1st Qu.:    0.00     1st Qu.:    0.0          1st Qu.:    0.0
#  Median :   84.95     Median :    0.0          Median :    0.0
#  Mean   : 1829.61     Mean   :  762.3          Mean   : 1135.4
#  3rd Qu.:  934.42     3rd Qu.:  324.6          3rd Qu.:  413.6
#  Max.   :84946.00     Max.   :54104.0          Max.   :82723.0
#
#  spanish_poor_english other_indo_euro_language other_indo_euro_poor_english
#  Min.   :    0.0      Min.   :    0.0          Min.   :    0.00
#  1st Qu.:    0.0      1st Qu.:    0.0          1st Qu.:    0.00
#  Median :    0.0      Median :    0.0          Median :    0.00
#  Mean   :  495.4      Mean   :  325.5          Mean   :  103.81
#  3rd Qu.:  134.5      3rd Qu.:  202.2          3rd Qu.:   26.48
#  Max.   :44842.0      Max.   :40436.0          Max.   :26483.00
#
#  asian_language     asian_poor_english other_language
#  Min.   :    0.00   Min.   :    0.0    Min.   :    0.00
#  1st Qu.:    0.00   1st Qu.:    0.0    1st Qu.:    0.00
#  Median :    0.00   Median :    0.0    Median :    0.00
#  Mean   :  289.15   Mean   :  138.5    Mean   :   79.59
#  3rd Qu.:   46.35   3rd Qu.:    0.0    3rd Qu.:   29.30
#  Max.   :46350.00   Max.   :35889.0    Max.   :29294.00
#
#  english_less_than_v_well total_pop_ancestory pop_american
#  Min.   :    0.00         Min.   :     0.0    Min.   :    0.00
#  1st Qu.:    0.00         1st Qu.:   688.4    1st Qu.:   32.06
#  Median :    0.00         Median :  2753.6    Median :  208.42
#  Mean   :   24.55         Mean   :  9443.2    Mean   :  656.54
#  3rd Qu.:    0.00         3rd Qu.: 12735.6    3rd Qu.:  801.60
#  Max.   :12035.00         Max.   :114734.0    Max.   :16031.00
#
#  pop_arab           pop_czech          pop_danish        pop_dutch
#  Min.   :    0.00   Min.   :   0.000   Min.   :   0.00   Min.   :    0.0
#  1st Qu.:    0.00   1st Qu.:   0.000   1st Qu.:   0.00   1st Qu.:    0.0
#  Median :    0.00   Median :   3.111   Median :   0.00   Median :   31.0
#  Mean   :   51.86   Mean   :  45.921   Mean   :  41.25   Mean   :  137.4
#  3rd Qu.:    0.00   3rd Qu.:  40.443   3rd Qu.:  30.06   3rd Qu.:  155.0
#  Max.   :32701.00   Max.   :3110.000   Max.   :3757.00   Max.   :15498.0
#
#  pop_english        pop_french         pop_french_canadian pop_german
#  Min.   :    0.00   Min.   :    0.00   Min.   :   0.00     Min.   :    0.0
#  1st Qu.:   49.01   1st Qu.:    0.00   1st Qu.:   0.00     1st Qu.:  109.7
#  Median :  245.07   Median :   63.66   Median :   0.00     Median :  466.2
#  Mean   :  782.34   Mean   :  263.07   Mean   :  62.49     Mean   : 1446.3
#  3rd Qu.:  963.94   3rd Qu.:  292.84   3rd Qu.:  47.65     3rd Qu.: 1700.3
#  Max.   :16337.00   Max.   :12731.00   Max.   :9529.00     Max.   :27423.0
#
#  pop_greek         pop_hungarian      pop_irish          pop_italian
#  Min.   :   0.00   Min.   :    0.00   Min.   :    0.00   Min.   :    0.00
#  1st Qu.:   0.00   1st Qu.:    0.00   1st Qu.:   58.69   1st Qu.:    0.00
#  Median :   0.00   Median :    0.00   Median :  313.01   Median :   61.01
#  Mean   :  39.43   Mean   :   44.50   Mean   : 1048.42   Mean   :  528.49
#  3rd Qu.:  28.89   3rd Qu.:   30.37   3rd Qu.: 1330.28   3rd Qu.:  457.55
#  Max.   :5776.00   Max.   :10122.00   Max.   :19562.00   Max.   :30502.00
#
#  pop_lithuanian    pop_norwegian      pop_polish         pop_portuguese
#  Min.   :   0.00   Min.   :    0.00   Min.   :    0.00   Min.   :    0.00
#  1st Qu.:   0.00   1st Qu.:    0.00   1st Qu.:    0.00   1st Qu.:    0.00
#  Median :   0.00   Median :   14.97   Median :   38.99   Median :    0.00
#  Mean   :  20.37   Mean   :  136.11   Mean   :  290.90   Mean   :   42.58
#  3rd Qu.:  12.54   3rd Qu.:   89.85   3rd Qu.:  253.41   3rd Qu.:   14.82
#  Max.   :1790.00   Max.   :14974.00   Max.   :19492.00   Max.   :14824.00
#
#  pop_russian        pop_scotch_irish  pop_scottish       pop_slovak
#  Min.   :    0.00   Min.   :   0.00   Min.   :   0.000   Min.   :   0.000
#  1st Qu.:    0.00   1st Qu.:   0.00   1st Qu.:   5.914   1st Qu.:   0.000
#  Median :    0.00   Median :  22.81   Median :  41.398   Median :   0.000
#  Mean   :   89.85   Mean   :  97.37   Mean   : 166.275   Mean   :  22.882
#  3rd Qu.:   53.24   3rd Qu.: 107.55   3rd Qu.: 195.162   3rd Qu.:   7.468
#  Max.   :13310.00   Max.   :3258.00   Max.   :2956.000   Max.   :3733.000
#
#  pop_subsaharan_africa pop_swedish       pop_swiss         pop_ukrainian
#  Min.   :    0.00      Min.   :   0.00   Min.   :   0.00   Min.   :   0.00
#  1st Qu.:    0.00      1st Qu.:   0.00   1st Qu.:   0.00   1st Qu.:   0.00
#  Median :    0.00      Median :  16.24   Median :   0.00   Median :   0.00
#  Mean   :   88.86      Mean   : 123.29   Mean   :  28.85   Mean   :  29.06
#  3rd Qu.:   24.47      3rd Qu.: 113.69   3rd Qu.:  24.73   3rd Qu.:  15.96
#  Max.   :12233.00      Max.   :8120.00   Max.   :3090.00   Max.   :5320.00
#
#  pop_welsh          pop_west_indian
#  Min.   :   0.000   Min.   :    0.0
#  1st Qu.:   0.000   1st Qu.:    0.0
#  Median :   9.496   Median :    0.0
#  Mean   :  55.209   Mean   :   81.8
#  3rd Qu.:  59.350   3rd Qu.:    0.0
#  Max.   :2373.000   Max.   :46449.0

# %%
acs_zcta_col <- acs_orig$ZCTA5
acs_full <- acs_orig[,-which(colnames(acs_orig) == "ZCTA5")]
dim(acs_full)
summary(acs_full)
# Out:
# [1] 32989   149
# Warning message in summary.H2OFrame(acs_full):
# "Approximated quantiles computed! If you are interested in exact quantiles, please pass the `exact_quantiles=TRUE` parameter."
#  total_households  family_households families_w_children_under_18
#  Min.   :    0.0   Min.   :    0.0   Min.   :    0.00
#  1st Qu.:  260.5   1st Qu.:  171.9   1st Qu.:   61.22
#  Median : 1042.1   Median :  716.2   Median :  275.51
#  Mean   : 3504.5   Mean   : 2326.3   Mean   : 1035.66
#  3rd Qu.: 4776.4   3rd Qu.: 3208.8   3rd Qu.: 1331.62
#  Max.   :43421.0   Max.   :28649.0   Max.   :15305.00
#
#  married_families  married_w_children_under_18 male_no_wife
#  Min.   :    0.0   Min.   :    0.00            Min.   :   0.000
#  1st Qu.:  138.6   1st Qu.:   34.06            1st Qu.:   8.168
#  Median :  554.5   Median :  192.98            Median :  44.924
#  Mean   : 1706.8   Mean   :  699.79            Mean   : 164.754
#  3rd Qu.: 2336.8   3rd Qu.:  874.10            3rd Qu.: 196.032
#  Max.   :19802.0   Max.   :11351.00            Max.   :4083.000
#
#  male_no_wife_w_children_under_18 female_no_husband
#  Min.   :   0.00                  Min.   :    0.00
#  1st Qu.:   0.00                  1st Qu.:   12.90
#  Median :  19.42                  Median :   90.29
#  Mean   :  79.55                  Mean   :  454.80
#  3rd Qu.:  94.95                  3rd Qu.:  515.96
#  Max.   :2157.00                  Max.   :12898.00
#
#  female_no_husband_w_children_under_18 nonfamily_households living_alone
#  Min.   :   0.000                      Min.   :    0.00     Min.   :    0.00
#  1st Qu.:   7.367                      1st Qu.:   53.14     1st Qu.:   58.78
#  Median :  51.569                      Median :  292.27     Median :  254.72
#  Mean   : 256.322                      Mean   : 1178.13     Mean   :  963.30
#  3rd Qu.: 279.946                      3rd Qu.: 1434.78     3rd Qu.: 1214.83
#  Max.   :7366.000                      Max.   :26569.00     Max.   :19593.00
#
#  living_alone_65_and_over households_w_people_under_18
#  Min.   :   0.00          Min.   :    0.00
#  1st Qu.:  23.43          1st Qu.:   68.96
#  Median : 101.54          Median :  310.34
#  Mean   : 342.41          Mean   : 1154.31
#  3rd Qu.: 445.23          3rd Qu.: 1499.97
#  Max.   :7810.00          Max.   :17240.00
#
#  households_w_people_over_65 average_household_size average_family_size
#  Min.   :    0.00            Min.   : 0.000         Min.   : 0.000
#  1st Qu.:   65.39            1st Qu.: 2.281         1st Qu.: 2.819
#  Median :  283.33            Median : 2.514         Median : 3.037
#  Mean   :  892.33            Mean   : 2.510         Mean   : 3.013
#  3rd Qu.: 1220.52            3rd Qu.: 2.746         3rd Qu.: 3.255
#  Max.   :21794.00            Max.   :14.530         Max.   :14.530
#
#  pop_in_households  pop_householder   pop_spouse        pop_child
#  Min.   :     0.0   Min.   :    0.0   Min.   :    0.0   Min.   :    0.0
#  1st Qu.:   571.8   1st Qu.:  260.5   1st Qu.:  138.5   1st Qu.:  137.1
#  Median :  2630.1   Median : 1042.1   Median :  554.0   Median :  731.4
#  Mean   :  9200.2   Mean   : 3504.5   Mean   : 1705.8   Mean   : 2811.0
#  3rd Qu.: 12350.2   3rd Qu.: 4776.4   3rd Qu.: 2334.5   3rd Qu.: 3565.7
#  Max.   :114353.0   Max.   :43421.0   Max.   :19783.0   Max.   :45713.0
#
#  pop_other_relatives pop_nonrelatives   pop_unmarried_partner males_15_and_over
#  Min.   :    0.00    Min.   :    0.00   Min.   :   0.00       Min.   :    0.0
#  1st Qu.:   21.87    1st Qu.:   15.96   1st Qu.:   8.25       1st Qu.:  277.5
#  Median :  131.20    Median :   95.77   Median :  53.62       Median : 1110.1
#  Mean   :  650.39    Mean   :  528.51   Mean   : 206.78       Mean   : 3698.0
#  3rd Qu.:  656.01    3rd Qu.:  542.71   3rd Qu.: 247.50       3rd Qu.: 5041.9
#  Max.   :21866.00    Max.   :15961.00   Max.   :4124.00       Max.   :46255.0
#
#  males_15_and_over_unmarried males_15_and_over_married
#  Min.   :    0.00            Min.   :    0.0
#  1st Qu.:   70.36            1st Qu.:  154.3
#  Median :  304.90            Median :  595.1
#  Mean   : 1310.73            Mean   : 1872.2
#  3rd Qu.: 1594.87            3rd Qu.: 2534.5
#  Max.   :23453.00            Max.   :22038.0
#
#  males_15_and_over_separated males_15_and_over_widowed
#  Min.   :   0.00             Min.   :   0.00
#  1st Qu.:   0.00             1st Qu.:   5.50
#  Median :  13.70             Median :  30.25
#  Mean   :  68.03             Mean   :  94.19
#  3rd Qu.:  75.33             3rd Qu.: 127.88
#  Max.   :1711.00             Max.   :1374.00
#
#  males_15_and_over_divorced females_15_and_over females_15_and_over_unmarried
#  Min.   :   0.00            Min.   :    0.0     Min.   :    0.0
#  1st Qu.:  26.52            1st Qu.:  285.3     1st Qu.:   46.6
#  Median : 114.92            Median : 1093.5     Median :  233.0
#  Mean   : 352.85            Mean   : 3892.1     Mean   : 1133.3
#  3rd Qu.: 481.78            3rd Qu.: 5277.3     3rd Qu.: 1304.7
#  Max.   :4419.00            Max.   :47542.0     Max.   :23297.0
#
#  females_15_and_over_married females_15_and_over_separated
#  Min.   :    0.0             Min.   :   0.00
#  1st Qu.:  151.5             1st Qu.:   0.00
#  Median :  584.4             Median :  16.52
#  Mean   : 1830.8             Mean   :  97.91
#  3rd Qu.: 2489.2             3rd Qu.: 105.73
#  Max.   :21644.0             Max.   :3303.00
#
#  females_15_and_over_widowed females_15_and_over_divorced women_birth_past_year
#  Min.   :   0.00             Min.   :   0.00              Min.   :   0.000
#  1st Qu.:  21.98             1st Qu.:  25.34              1st Qu.:   3.678
#  Median : 109.88             Median : 120.38              Median :  25.746
#  Mean   : 359.88             Mean   : 470.14              Mean   : 123.410
#  3rd Qu.: 488.97             3rd Qu.: 614.59              3rd Qu.: 143.442
#  Max.   :5493.00             Max.   :6335.00              Max.   :3677.000
#                                                           NA's   :441
#  unmarried_women_birth_past_year unmarried_women_birth_past_year_per_1000
#  Min.   :   0.000                Min.   :   0.00
#  1st Qu.:   0.000                1st Qu.:   0.00
#  Median :   5.056                Median :  14.01
#  Mean   :  43.868                Mean   :  35.03
#  3rd Qu.:  40.448                3rd Qu.:  46.05
#  Max.   :2527.000                Max.   :1000.00
#  NA's   :441                     NA's   :441
#  women_birth_past_year_per_1000 women_15_to_19_birth_past_year_per_1000
#  Min.   :   0.00                Min.   :   0.000
#  1st Qu.:  15.02                1st Qu.:   0.000
#  Median :  44.04                Median :   0.000
#  Mean   :  52.78                Mean   :  21.418
#  3rd Qu.:  68.07                3rd Qu.:   7.007
#  Max.   :1000.00                Max.   :1000.000
#  NA's   :441                    NA's   :441
#  women_20_to_34_birth_past_year_per_1000
#  Min.   :   0.00
#  1st Qu.:  11.01
#  Median :  83.08
#  Mean   : 104.20
#  3rd Qu.: 137.14
#  Max.   :1000.00
#  NA's   :441
#  women_35_to_50_birth_past_year_per_1000 grdparents_live_w_grdchildren
#  Min.   :   0.000                        Min.   :   0.00
#  1st Qu.:   0.000                        1st Qu.:   0.00
#  Median :   1.001                        Median :  49.01
#  Mean   :  18.659                        Mean   : 212.91
#  3rd Qu.:  25.025                        3rd Qu.: 224.06
#  Max.   :1000.000                        Max.   :7001.00
#  NA's   :441
#  grdparents_live_w_resp_grdchildren resp_grdchildren_less_1yr
#  Min.   :   0.00                    Min.   :  0.00
#  1st Qu.:   0.00                    1st Qu.:  0.00
#  Median :  19.69                    Median :  0.00
#  Mean   :  82.87                    Mean   : 17.78
#  3rd Qu.:  94.08                    3rd Qu.: 18.00
#  Max.   :2187.00                    Max.   :604.00
#
#  resp_grdchildren_1_or_2yrs resp_grdchildren_3_or_4yrs
#  Min.   :  0.00             Min.   :  0.0
#  1st Qu.:  0.00             1st Qu.:  0.0
#  Median :  0.00             Median :  0.0
#  Mean   : 19.72             Mean   : 13.8
#  3rd Qu.: 20.00             3rd Qu.: 13.0
#  Max.   :510.00             Max.   :556.0
#
#  resp_grdchildren_5yrs_or_more grdparents_resp_grdchildren
#  Min.   :  0.00                Min.   :   0.00
#  1st Qu.:  0.00                1st Qu.:   0.00
#  Median :  4.00                Median :  19.69
#  Mean   : 31.58                Mean   :  82.87
#  3rd Qu.: 35.00                3rd Qu.:  94.08
#  Max.   :796.00                Max.   :2187.00
#
#  female_grdparents_resp_grdchildren married_grdparents_resp_grdchildren
#  Min.   :   0.00                    Min.   :   0.00
#  1st Qu.:   0.00                    1st Qu.:   0.00
#  Median :  10.95                    Median :  12.39
#  Mean   :  51.93                    Mean   :  58.41
#  3rd Qu.:  57.50                    3rd Qu.:  66.61
#  Max.   :1368.00                    Max.   :1548.00
#
#  pop_3_and_over_in_school nursery_and_preschool kindergarten
#  Min.   :    0.0          Min.   :   0.000      Min.   :   0.000
#  1st Qu.:  119.9          1st Qu.:   3.237      1st Qu.:   3.222
#  Median :  639.6          Median :  35.607      Median :  32.220
#  Mean   : 2504.5          Mean   : 151.904      Mean   : 127.568
#  3rd Qu.: 3198.2          3rd Qu.: 190.983      3rd Qu.: 157.878
#  Max.   :39977.0          Max.   :3236.000      Max.   :3221.000
#
#  elementary_school  high_school       college_or_graduate_school
#  Min.   :    0.00   Min.   :   0.00   Min.   :    0.0
#  1st Qu.:   50.55   1st Qu.:  27.77   1st Qu.:    0.0
#  Median :  269.58   Median : 138.82   Median :  109.6
#  Mean   :  994.16   Mean   : 519.95   Mean   :  711.0
#  3rd Qu.: 1263.67   3rd Qu.: 657.11   3rd Qu.:  731.0
#  Max.   :16848.00   Max.   :9254.00   Max.   :36548.0
#
#  pop_25_years_and_over less_than_9th_grade high_school_no_diploma
#  Min.   :    0         Min.   :    0.00    Min.   :    0.00
#  1st Qu.:  439         1st Qu.:    0.00    1st Qu.:   26.46
#  Median : 1829         Median :   72.02    Median :  145.52
#  Mean   : 6262         Mean   :  372.01    Mean   :  503.60
#  3rd Qu.: 8634         3rd Qu.:  312.09    3rd Qu.:  582.08
#  Max.   :73169         Max.   :24006.00    Max.   :13228.00
#
#  high_school_graduate college_no_degree  associate_degree  bachelors_degree
#  Min.   :    0.0      Min.   :    0.00   Min.   :   0.00   Min.   :    0.00
#  1st Qu.:  171.6      1st Qu.:   84.98   1st Qu.:  31.62   1st Qu.:   24.26
#  Median :  661.8      Median :  390.93   Median : 145.45   Median :  194.06
#  Mean   : 1760.6      Mean   : 1330.58   Mean   : 489.11   Mean   : 1130.24
#  3rd Qu.: 2377.5      3rd Qu.: 1750.69   3rd Qu.: 638.72   3rd Qu.: 1237.11
#  Max.   :24509.0      Max.   :16996.00   Max.   :6323.00   Max.   :24256.00
#
#  graduate_or_prof_degree pct_high_school_grad_or_higher
#  Min.   :    0.00        Min.   :  0.00
#  1st Qu.:    0.00        1st Qu.: 80.50
#  Median :   84.96        Median : 88.00
#  Mean   :  675.88        Mean   : 84.72
#  3rd Qu.:  651.34        3rd Qu.: 93.00
#  Max.   :28318.00        Max.   :100.00
#
#  pct_bachelors_degree_or_higher civilian_18_and_over civilian_veterans
#  Min.   :  0.00                 Min.   :    0.0      Min.   :    0.0
#  1st Qu.: 11.10                 1st Qu.:  502.9      1st Qu.:   51.4
#  Median : 17.50                 Median : 2095.4      Median :  218.5
#  Mean   : 21.86                 Mean   : 7171.1      Mean   :  644.5
#  3rd Qu.: 28.30                 3rd Qu.: 9806.7      3rd Qu.:  873.9
#  Max.   :100.00                 Max.   :83817.0      Max.   :12850.0
#
#  pop_civilian_noninst pop_civilian_w_disability age_under_18
#  Min.   :     0.0     Min.   :    0.00          Min.   :    0.0
#  1st Qu.:   682.9     1st Qu.:   88.04          1st Qu.:  122.1
#  Median :  2617.9     Median :  381.52          Median :  610.4
#  Mean   :  9289.3     Mean   : 1126.69          Mean   : 2235.1
#  3rd Qu.: 12520.4     3rd Qu.: 1540.77          3rd Qu.: 2848.4
#  Max.   :113821.0     Max.   :14673.00          Max.   :40691.0
#
#  age_under_18_w_disability age_18_to_64      age_18_to_64_w_disability
#  Min.   :   0.00           Min.   :    0.0   Min.   :    0.00
#  1st Qu.:   0.00           1st Qu.:  363.7   1st Qu.:   41.22
#  Median :  24.23           Median : 1600.3   Median :  195.79
#  Mean   :  90.11           Mean   : 5825.1   Mean   :  588.18
#  3rd Qu.: 109.03           3rd Qu.: 7710.3   3rd Qu.:  772.88
#  Max.   :2422.00           Max.   :72738.0   Max.   :10304.00
#
#  age_65_and_over   age_65_and_over_w_disability pop_1_and_over
#  Min.   :    0.0   Min.   :   0.00              Min.   :     0.0
#  1st Qu.:  103.7   1st Qu.:  38.42              1st Qu.:   681.3
#  Median :  415.0   Median : 153.70              Median :  2725.3
#  Mean   : 1229.0   Mean   : 448.39              Mean   :  9329.8
#  3rd Qu.: 1659.9   3rd Qu.: 614.78              3rd Qu.: 12604.7
#  Max.   :34581.0   Max.   :9605.00              Max.   :113555.0
#
#  res_same_house     res_diff_house_in_us res_same_county    res_diff_county
#  Min.   :     0.0   Min.   :    0.00     Min.   :    0.00   Min.   :    0.00
#  1st Qu.:   601.3   1st Qu.:   54.65     1st Qu.:   16.63   1st Qu.:   13.29
#  Median :  2405.1   Median :  273.27     Median :  133.06   Median :  119.59
#  Mean   :  7920.2   Mean   : 1354.58     Mean   :  848.79   Mean   :  505.79
#  3rd Qu.: 10822.9   3rd Qu.: 1584.97     3rd Qu.:  898.18   3rd Qu.:  597.96
#  Max.   :100211.0   Max.   :27326.00     Max.   :16632.00   Max.   :13287.00
#
#  res_diff_county_same_state res_diff_county_and_state res_abroad
#  Min.   :    0.00           Min.   :    0.00          Min.   :   0.00
#  1st Qu.:    0.00           1st Qu.:    0.00          1st Qu.:   0.00
#  Median :   59.25           Median :   30.68          Median :   0.00
#  Mean   :  294.71           Mean   :  211.07          Mean   :  55.00
#  3rd Qu.:  319.95           3rd Qu.:  214.79          3rd Qu.:  31.43
#  Max.   :11849.00           Max.   :10227.00          Max.   :3928.00
#
#  total_pop_place_of_birth pop_native        native_born_in_us
#  Min.   :     0.0         Min.   :    0.0   Min.   :    0.0
#  1st Qu.:   688.4         1st Qu.:  617.6   1st Qu.:  689.7
#  Median :  2753.6         Median : 2646.9   Median : 2586.4
#  Mean   :  9443.2         Mean   : 8220.3   Mean   : 8088.3
#  3rd Qu.: 12735.6         3rd Qu.:11646.2   3rd Qu.:11466.6
#  Max.   :114734.0         Max.   :88228.0   Max.   :86214.0
#
#  born_state_of_residence born_different_state born_islands_american_abroad
#  Min.   :    0.0         Min.   :    0.0      Min.   :    0.0
#  1st Qu.:  422.3         1st Qu.:  137.0      1st Qu.:    0.0
#  Median : 1829.8         Median :  593.8      Median :    0.0
#  Mean   : 5547.3         Mean   : 2541.0      Mean   :  132.1
#  3rd Qu.: 7460.0         3rd Qu.: 2969.1      3rd Qu.:  100.1
#  Max.   :70376.0         Max.   :45677.0      Max.   :12507.0
#
#  total_pop_foreign_born pop_foreign_born  foreign_born_naturalized_us_citizen
#  Min.   :    0.0        Min.   :    0.0   Min.   :    0.0
#  1st Qu.:    0.0        1st Qu.:    0.0   1st Qu.:    0.0
#  Median :    0.0        Median :    0.0   Median :    0.0
#  Mean   : 1222.8        Mean   : 1222.8   Mean   :  551.9
#  3rd Qu.:  624.8        3rd Qu.:  624.8   3rd Qu.:  260.3
#  Max.   :69424.0        Max.   :69424.0   Max.   :32541.0
#
#  foreign_born_not_us_citizen pop_born_outside_us native
#  Min.   :    0.0             Min.   :    0.00    Min.   :    0.0
#  1st Qu.:    0.0             1st Qu.:    0.00    1st Qu.:    0.0
#  Median :    0.0             Median :   70.78    Median :    0.0
#  Mean   :  670.9             Mean   : 1354.92    Mean   :  132.1
#  3rd Qu.:  285.2             3rd Qu.:  707.76    3rd Qu.:  100.1
#  Max.   :47531.0             Max.   :70775.00    Max.   :12507.0
#
#  native_entered_2010_or_later native_entered_before_2010 foreign_born
#  Min.   :   0.000             Min.   :    0.00           Min.   :    0.0
#  1st Qu.:   0.000             1st Qu.:    0.00           1st Qu.:    0.0
#  Median :   0.000             Median :   11.33           Median :    0.0
#  Mean   :   5.674             Mean   :  126.41           Mean   : 1222.8
#  3rd Qu.:   0.000             3rd Qu.:   90.67           3rd Qu.:  624.8
#  Max.   :1174.000             Max.   :11333.00           Max.   :69424.0
#
#  foreign_born_entered_2010_or_later foreign_born_entered_before_2010
#  Min.   :   0.00                    Min.   :    0.0
#  1st Qu.:   0.00                    1st Qu.:    0.0
#  Median :   0.00                    Median :    0.0
#  Mean   :  56.98                    Mean   : 1165.9
#  3rd Qu.:  18.69                    3rd Qu.:  534.3
#  Max.   :3737.00                    Max.   :66787.0
#
#  foreign_born_excl_born_at_sea foreign_born_europe foreign_born_asia
#  Min.   :    0.0               Min.   :    0.00    Min.   :    0.00
#  1st Qu.:    0.0               1st Qu.:    0.00    1st Qu.:    0.00
#  Median :    0.0               Median :    0.00    Median :    0.00
#  Mean   : 1222.8               Mean   :  146.12    Mean   :  352.38
#  3rd Qu.:  624.8               3rd Qu.:   86.47    3rd Qu.:   97.62
#  Max.   :69424.0               Max.   :28823.00    Max.   :48809.00
#
#  foreign_born_africa foreign_born_oceania foreign_born_latin_america
#  Min.   :   0.000    Min.   :   0.000     Min.   :    0.0
#  1st Qu.:   0.000    1st Qu.:   0.000     1st Qu.:    0.0
#  Median :   0.000    Median :   0.000     Median :    0.0
#  Mean   :  50.435    Mean   :   6.834     Mean   :  642.2
#  3rd Qu.:   7.627    3rd Qu.:   0.000     3rd Qu.:  165.1
#  Max.   :7626.000    Max.   :2614.000     Max.   :55018.0
#
#  foreign_born_northern_america pop_5_and_over     english_language_only
#  Min.   :   0.00               Min.   :     0.0   Min.   :    0.0
#  1st Qu.:   0.00               1st Qu.:   634.2   1st Qu.:  602.1
#  Median :   0.00               Median :  2536.7   Median : 2341.4
#  Mean   :  24.83               Mean   :  8835.3   Mean   : 7005.7
#  3rd Qu.:  15.18               3rd Qu.: 11943.8   3rd Qu.: 9967.8
#  Max.   :2168.00               Max.   :105696.0   Max.   :66897.0
#
#  non_english_language non_english_poor_english spanish_language
#  Min.   :    0.00     Min.   :    0.0          Min.   :    0.0
#  1st Qu.:    0.00     1st Qu.:    0.0          1st Qu.:    0.0
#  Median :   84.95     Median :    0.0          Median :    0.0
#  Mean   : 1829.61     Mean   :  762.3          Mean   : 1135.4
#  3rd Qu.:  934.42     3rd Qu.:  324.6          3rd Qu.:  413.6
#  Max.   :84946.00     Max.   :54104.0          Max.   :82723.0
#
#  spanish_poor_english other_indo_euro_language other_indo_euro_poor_english
#  Min.   :    0.0      Min.   :    0.0          Min.   :    0.00
#  1st Qu.:    0.0      1st Qu.:    0.0          1st Qu.:    0.00
#  Median :    0.0      Median :    0.0          Median :    0.00
#  Mean   :  495.4      Mean   :  325.5          Mean   :  103.81
#  3rd Qu.:  134.5      3rd Qu.:  202.2          3rd Qu.:   26.48
#  Max.   :44842.0      Max.   :40436.0          Max.   :26483.00
#
#  asian_language     asian_poor_english other_language
#  Min.   :    0.00   Min.   :    0.0    Min.   :    0.00
#  1st Qu.:    0.00   1st Qu.:    0.0    1st Qu.:    0.00
#  Median :    0.00   Median :    0.0    Median :    0.00
#  Mean   :  289.15   Mean   :  138.5    Mean   :   79.59
#  3rd Qu.:   46.35   3rd Qu.:    0.0    3rd Qu.:   29.30
#  Max.   :46350.00   Max.   :35889.0    Max.   :29294.00
#
#  english_less_than_v_well total_pop_ancestory pop_american
#  Min.   :    0.00         Min.   :     0.0    Min.   :    0.00
#  1st Qu.:    0.00         1st Qu.:   688.4    1st Qu.:   32.06
#  Median :    0.00         Median :  2753.6    Median :  208.42
#  Mean   :   24.55         Mean   :  9443.2    Mean   :  656.54
#  3rd Qu.:    0.00         3rd Qu.: 12735.6    3rd Qu.:  801.60
#  Max.   :12035.00         Max.   :114734.0    Max.   :16031.00
#
#  pop_arab           pop_czech          pop_danish        pop_dutch
#  Min.   :    0.00   Min.   :   0.000   Min.   :   0.00   Min.   :    0.0
#  1st Qu.:    0.00   1st Qu.:   0.000   1st Qu.:   0.00   1st Qu.:    0.0
#  Median :    0.00   Median :   3.111   Median :   0.00   Median :   31.0
#  Mean   :   51.86   Mean   :  45.921   Mean   :  41.25   Mean   :  137.4
#  3rd Qu.:    0.00   3rd Qu.:  40.443   3rd Qu.:  30.06   3rd Qu.:  155.0
#  Max.   :32701.00   Max.   :3110.000   Max.   :3757.00   Max.   :15498.0
#
#  pop_english        pop_french         pop_french_canadian pop_german
#  Min.   :    0.00   Min.   :    0.00   Min.   :   0.00     Min.   :    0.0
#  1st Qu.:   49.01   1st Qu.:    0.00   1st Qu.:   0.00     1st Qu.:  109.7
#  Median :  245.07   Median :   63.66   Median :   0.00     Median :  466.2
#  Mean   :  782.34   Mean   :  263.07   Mean   :  62.49     Mean   : 1446.3
#  3rd Qu.:  963.94   3rd Qu.:  292.84   3rd Qu.:  47.65     3rd Qu.: 1700.3
#  Max.   :16337.00   Max.   :12731.00   Max.   :9529.00     Max.   :27423.0
#
#  pop_greek         pop_hungarian      pop_irish          pop_italian
#  Min.   :   0.00   Min.   :    0.00   Min.   :    0.00   Min.   :    0.00
#  1st Qu.:   0.00   1st Qu.:    0.00   1st Qu.:   58.69   1st Qu.:    0.00
#  Median :   0.00   Median :    0.00   Median :  313.01   Median :   61.01
#  Mean   :  39.43   Mean   :   44.50   Mean   : 1048.42   Mean   :  528.49
#  3rd Qu.:  28.89   3rd Qu.:   30.37   3rd Qu.: 1330.28   3rd Qu.:  457.55
#  Max.   :5776.00   Max.   :10122.00   Max.   :19562.00   Max.   :30502.00
#
#  pop_lithuanian    pop_norwegian      pop_polish         pop_portuguese
#  Min.   :   0.00   Min.   :    0.00   Min.   :    0.00   Min.   :    0.00
#  1st Qu.:   0.00   1st Qu.:    0.00   1st Qu.:    0.00   1st Qu.:    0.00
#  Median :   0.00   Median :   14.97   Median :   38.99   Median :    0.00
#  Mean   :  20.37   Mean   :  136.11   Mean   :  290.90   Mean   :   42.58
#  3rd Qu.:  12.54   3rd Qu.:   89.85   3rd Qu.:  253.41   3rd Qu.:   14.82
#  Max.   :1790.00   Max.   :14974.00   Max.   :19492.00   Max.   :14824.00
#
#  pop_russian        pop_scotch_irish  pop_scottish       pop_slovak
#  Min.   :    0.00   Min.   :   0.00   Min.   :   0.000   Min.   :   0.000
#  1st Qu.:    0.00   1st Qu.:   0.00   1st Qu.:   5.914   1st Qu.:   0.000
#  Median :    0.00   Median :  22.81   Median :  41.398   Median :   0.000
#  Mean   :   89.85   Mean   :  97.37   Mean   : 166.275   Mean   :  22.882
#  3rd Qu.:   53.24   3rd Qu.: 107.55   3rd Qu.: 195.162   3rd Qu.:   7.468
#  Max.   :13310.00   Max.   :3258.00   Max.   :2956.000   Max.   :3733.000
#
#  pop_subsaharan_africa pop_swedish       pop_swiss         pop_ukrainian
#  Min.   :    0.00      Min.   :   0.00   Min.   :   0.00   Min.   :   0.00
#  1st Qu.:    0.00      1st Qu.:   0.00   1st Qu.:   0.00   1st Qu.:   0.00
#  Median :    0.00      Median :  16.24   Median :   0.00   Median :   0.00
#  Mean   :   88.86      Mean   : 123.29   Mean   :  28.85   Mean   :  29.06
#  3rd Qu.:   24.47      3rd Qu.: 113.69   3rd Qu.:  24.73   3rd Qu.:  15.96
#  Max.   :12233.00      Max.   :8120.00   Max.   :3090.00   Max.   :5320.00
#
#  pop_welsh          pop_west_indian
#  Min.   :   0.000   Min.   :    0.0
#  1st Qu.:   0.000   1st Qu.:    0.0
#  Median :   9.496   Median :    0.0
#  Mean   :  55.209   Mean   :   81.8
#  3rd Qu.:  59.350   3rd Qu.:    0.0
#  Max.   :2373.000   Max.   :46449.0

# %% [markdown]
# After removing the zip code column, we build a GLRM model out of the ACS data with k=10.

# %%
acs_model <- h2o.glrm(training_frame = acs_full, k = 10, transform = "STANDARDIZE", 
                      loss = "Quadratic", regularization_x = "Quadratic", 
                      regularization_y = "L1", max_iterations = 100, gamma_x = 0.25, gamma_y = 0.5)
plot(acs_model)
# Out:
#   |======================================================================| 100%
# Plot with title "Objective Function Value per Iteration"

# %% [markdown]
# Each row of X represents the coefficients needed represent a row of ACS dataset using the archetypes in Y.  For cities that are similar, you will expect them to have similar X values.

# %%
zcta_arch_x <- h2o.getFrame(acs_model@model$representation_name)
head(zcta_arch_x)
# Out:
#   Arch1     Arch2      Arch3        Arch4        Arch5       Arch6
# 1 0.1226900 0.10114839  0.028527685 -0.001968197 -0.03941039 0.10117091
# 2 0.3183573 0.02222733  0.217931759  0.487373559 -0.27318003 0.03525323
# 3 0.3446143 0.02514467 -0.003790869  0.165649992 -0.07789903 0.13530153
# 4 0.1401720 0.01909868 -0.077744700 -0.018909635  0.02185653 0.14824981
# 5 0.1802456 0.04066796 -0.049691153  0.060816438 -0.06369125 0.12895632
# 6 0.1899590 0.02169945 -0.076339177 -0.038712830  0.04258228 0.08568675
#   Arch7      Arch8       Arch9         Arch10
# 1 0.47409872  0.11584882 -9.650139e-02 -0.04819020
# 2 0.18940673  0.14503722 -1.142668e-01 -0.15292968
# 3 0.04036819 -0.16998781  4.056439e-02 -0.09810906
# 4 0.16459778  0.04804312 -8.230556e-03 -0.03363243
# 5 0.42084607  0.04416351 -7.232527e-02 -0.02965067
# 6 0.02187918  0.07669749 -7.383714e-05 -0.05094124

# %%
idx <- ((acs_zcta_col == "10065") |   # Manhattan, NY (Upper East Side)
        (acs_zcta_col == "11219") |   # Manhattan, NY (East Harlem)
        (acs_zcta_col == "66753") |   # McCune, KS
        (acs_zcta_col == "84104") |   # Salt Lake City, UT
        (acs_zcta_col == "94086") |   # Sunnyvale, CA
        (acs_zcta_col == "95014"))    # Cupertino, CA

city_arch <- as.data.frame(zcta_arch_x[idx,1:2])
xeps <- (max(city_arch[,1]) - min(city_arch[,1])) / 10
yeps <- (max(city_arch[,2]) - min(city_arch[,2])) / 10
xlims <- c(min(city_arch[,1]) - xeps, max(city_arch[,1]) + xeps)
ylims <- c(min(city_arch[,2]) - yeps, max(city_arch[,2]) + yeps)
plot(city_arch[,1], city_arch[,2], xlim = xlims, ylim = ylims, xlab = "First Archetype", ylab = "Second Archetype", main = "Archetype Representation of Zip Code Tabulation Areas")
text(city_arch[,1], city_arch[,2], labels = c("Upper East Side", "East Harlem", "McCune", "Salt Lake City", "Sunnyvale", "Cupertino"), pos = 1)
# Out:
# Plot with title "Archetype Representation of Zip Code Tabulation Areas"

# %% [markdown]
# Cities like Sunnyvale and Cupertino, they are more similar than with East Harlem.  Note that we are able to cluster coefficients of archetypes of similar cities today, we have no idea what each archetype actually represent.  This is a general problem with machine learning.

# %% [markdown]
# ## WHD Data
#
# Next, we build a deeplearning model on the WHD dataset to predict repeat and/or willful violators.  For comparison purposes, we will train a model using the original dataset, the original dataset with the zip code column replaced by the compressed GLRM representation (the X matrix) and the data with the zip code column replaced with all the demographic features in the ACS dataset.

# %%
#filename <- "http://s3.amazonaws.com/h2o-public-test-data/bigdata/laptop/census/whd_zcta_cleaned.zip"
filename <- "../../data/glrm/whd_zcta_cleaned.zip"
whd_zcta <- h2o.importFile(path = filename, col.types = c(rep("enum", 7), rep("numeric", 97)))
split <- h2o.runif(whd_zcta)
train <- whd_zcta[split <= 0.8,]
test <- whd_zcta[split > 0.8,]
myY <- "flsa_repeat_violator"
myX <- setdiff(5:ncol(train), which(colnames(train) == myY))
orig_time <- system.time(dl_orig <- h2o.deeplearning(x = myX, y = myY, training_frame = train, 
                                                     validation_frame = test, distribution = "multinomial",
                                                     epochs = 0.1, hidden = c(50,50,50)))
# Out:
#   |======================================================================| 100%
# Warning message in .h2o.startModelJob(algo, params, h2oRestApiVersion):
# "Dropping bad and constant columns: [flsa_smwap_violtn_cnt, flsa_smwap_bw_atp_amt, flsa_smwl_ee_atp_cnt, sraw_bw_atp_amt, sraw_ee_atp_cnt, flsa_smwap_ee_atp_cnt, flsa_smwl_violtn_cnt, flsa_smwmg_bw_atp_amt, osha_bw_atp_amt, osha_ee_atp_cnt, flsa_smwmg_ee_atp_cnt, crew_ee_atp_cnt, sraw_violtn_cnt, crew_bw_atp_amt, flsa_smwl_bw_atp_amt, flsa_smwmg_violtn_cnt].
# "
#   |======================================================================| 100%

# %%
zcta_arch_x$zcta5_cd <- acs_zcta_col
whd_arch <- h2o.merge(whd_zcta, zcta_arch_x, all.x = TRUE, all.y = FALSE)
whd_arch$zcta5_cd <- NULL
train_mod <- whd_arch[split <= 0.8,]
test_mod  <- whd_arch[split > 0.8,]
myX <- setdiff(5:ncol(train_mod), which(colnames(train_mod) == myY))
mod_time <- system.time(dl_mod <- h2o.deeplearning(x = myX, y = myY, training_frame = train_mod, 
                                                   validation_frame = test_mod, distribution = "multinomial",
                                                   epochs = 0.1, hidden = c(50,50,50)))
# Out:
# Warning message in .h2o.startModelJob(algo, params, h2oRestApiVersion):
# "Dropping bad and constant columns: [flsa_smwap_violtn_cnt, flsa_smwap_bw_atp_amt, flsa_smwl_ee_atp_cnt, sraw_bw_atp_amt, sraw_ee_atp_cnt, flsa_smwap_ee_atp_cnt, flsa_smwl_violtn_cnt, flsa_smwmg_bw_atp_amt, osha_bw_atp_amt, osha_ee_atp_cnt, flsa_smwmg_ee_atp_cnt, crew_ee_atp_cnt, sraw_violtn_cnt, crew_bw_atp_amt, flsa_smwl_bw_atp_amt, flsa_smwmg_violtn_cnt].
# "
#   |======================================================================| 100%

# %%
colnames(acs_orig)[1] <- "zcta5_cd"
whd_acs <- h2o.merge(whd_zcta, acs_orig, all.x = TRUE, all.y = FALSE)
train_comb <- whd_acs[split <= 0.8,]
test_comb <- whd_acs[split > 0.8,]
myX <- setdiff(5:ncol(train_comb), which(colnames(train_comb) == myY))
comb_time <- system.time(dl_comb <- h2o.deeplearning(x = myX, y = myY, training_frame = train_comb,
                                                     validation_frame = test_comb, distribution = "multinomial",
                                                     epochs = 0.1, hidden = c(50,50,50)))
# Out:
# Warning message in .h2o.startModelJob(algo, params, h2oRestApiVersion):
# "Dropping bad and constant columns: [flsa_smwap_violtn_cnt, flsa_smwap_bw_atp_amt, flsa_smwl_ee_atp_cnt, sraw_bw_atp_amt, sraw_ee_atp_cnt, flsa_smwap_ee_atp_cnt, flsa_smwl_violtn_cnt, flsa_smwmg_bw_atp_amt, osha_bw_atp_amt, osha_ee_atp_cnt, flsa_smwmg_ee_atp_cnt, crew_ee_atp_cnt, sraw_violtn_cnt, crew_bw_atp_amt, flsa_smwl_bw_atp_amt, flsa_smwmg_violtn_cnt].
# "
#   |======================================================================| 100%

# %%
data.frame(original = c(orig_time[3], h2o.logloss(dl_orig, train = TRUE), h2o.logloss(dl_orig, valid = TRUE)),
              reduced  = c(mod_time[3], h2o.logloss(dl_mod, train = TRUE), h2o.logloss(dl_mod, valid = TRUE)),
           combined = c(comb_time[3], h2o.logloss(dl_comb, train = TRUE), h2o.logloss(dl_comb, valid = TRUE)),
           row.names = c("runtime", "train_logloss", "test_logloss"))
# Out:
#               original   reduced   combined
# runtime       22.3220000 4.5360000 7.0370000
# train_logloss  0.1770882 0.1839663 0.2241933
# test_logloss   0.1910951 0.1982931 0.2537514

# %% [markdown]
# Compare the performance between the three models. We see that the model built on the reduced WHD data set finishes almost 10 times faster than the model using the original data set, and it yields a lower log-loss error. The model with the combined WHD-ACS data set does not improve significantly on this error. We can conclude that our GLRM compressed the ZCTA demographics with little informational loss.

# %%
h2o.shutdown(prompt = FALSE)
# Out:
# [1] TRUE
